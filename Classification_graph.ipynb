8/8 [==============================] - 78s 10s/step - loss: 0.1047 - acc: 1.0000 - val_loss: 0.1047 - val_acc: 1.0000
Epoch 47/60
8/8 [==============================] - 79s 10s/step - loss: 0.1045 - acc: 1.0000 - val_loss: 0.1046 - val_acc: 1.0000
Epoch 48/60
8/8 [==============================] - 74s 9s/step - loss: 0.1044 - acc: 1.0000 - val_loss: 0.1045 - val_acc: 1.0000
Epoch 49/60
8/8 [==============================] - 75s 9s/step - loss: 0.1042 - acc: 1.0000 - val_loss: 0.1043 - val_acc: 1.0000
Epoch 50/60
8/8 [==============================] - 71s 9s/step - loss: 0.1041 - acc: 1.0000 - val_loss: 0.1042 - val_acc: 1.0000
Epoch 51/60
8/8 [==============================] - 79s 10s/step - loss: 0.1040 - acc: 1.0000 - val_loss: 0.1040 - val_acc: 1.0000
Epoch 52/60
8/8 [==============================] - 78s 10s/step - loss: 0.1039 - acc: 1.0000 - val_loss: 0.1039 - val_acc: 1.0000
Epoch 53/60
8/8 [==============================] - 78s 10s/step - loss: 0.1037 - acc: 1.0000 - val_loss: 0.1038 - val_acc: 1.0000
Epoch 54/60
8/8 [==============================] - 75s 9s/step - loss: 0.1036 - acc: 1.0000 - val_loss: 0.1037 - val_acc: 1.0000
Epoch 55/60
8/8 [==============================] - 80s 10s/step - loss: 0.1035 - acc: 1.0000 - val_loss: 0.1036 - val_acc: 1.0000
Epoch 56/60
8/8 [==============================] - 84s 10s/step - loss: 0.1034 - acc: 1.0000 - val_loss: 0.1035 - val_acc: 1.0000
Epoch 57/60
8/8 [==============================] - 83s 10s/step - loss: 0.1033 - acc: 1.0000 - val_loss: 0.1034 - val_acc: 1.0000
Epoch 58/60
8/8 [==============================] - 83s 10s/step - loss: 0.1032 - acc: 1.0000 - val_loss: 0.1033 - val_acc: 1.0000
Epoch 59/60
8/8 [==============================] - 83s 10s/step - loss: 0.1031 - acc: 1.0000 - val_loss: 0.1032 - val_acc: 1.0000
Epoch 60/60
8/8 [==============================] - 83s 10s/step - loss: 0.1031 - acc: 1.0000 - val_loss: 0.1032 - val_acc: 1.0000

	Training time: 5722.178082227707

3/3 [==============================] - 5s 1s/step
test Accuraccy: 1.0000, test F1: 1.0000

"""

# Define regular expressions to extract information
epoch_pattern = re.compile(r"Epoch (\d+/\d+)")
metrics_pattern = re.compile(r"loss: ([0-9.]+) - acc: ([0-9.]+) - val_loss: ([0-9.]+) - val_acc: ([0-9.]+)")

# Initialize lists to store the data
epochs = []
losses = []
accs = []
val_losses = []
val_accs = []

current_epoch = None

# Split the log by lines
for line in log.split("\n"):
    epoch_match = epoch_pattern.match(line)
    if epoch_match:
        current_epoch = epoch_match.group(1)
    else:
        metrics_match = metrics_pattern.search(line)
        if metrics_match:
            losses.append(float(metrics_match.group(1)))
            accs.append(float(metrics_match.group(2)))
            val_losses.append(float(metrics_match.group(3)))
            val_accs.append(float(metrics_match.group(4)))
            epochs.append(current_epoch)

# Create a DataFrame
df = pd.DataFrame({
    'epoch': epochs,
    'loss': losses,
    'acc': accs,
    'val_loss': val_losses,
    'val_acc': val_accs
})

# Print the DataFrame
print(df)
# Out:
#     epoch     loss     acc  val_loss  val_acc
# 0    1/60  59.9190  0.5387    5.7027   0.4239
# 1    2/60   2.4419  0.5145    0.9631   0.5761
# 2    3/60   1.6050  0.5557    1.2346   0.5761
# 3    4/60   1.0432  0.5557    0.7356   0.5870
# 4    5/60   0.7163  0.6138    0.6010   0.8913
# 5    6/60   0.4980  0.9104    0.3654   0.9565
# 6    7/60   0.2829  0.9746    0.2035   0.9783
# 7    8/60   0.1780  0.9952    0.1479   1.0000
# 8    9/60   0.1525  0.9988    0.1305   1.0000
# 9   10/60   0.1325  0.9988    0.1359   1.0000
# 10  11/60   0.1296  0.9988    0.1271   1.0000
# 11  12/60   0.1255  1.0000    0.1259   1.0000
# 12  13/60   0.1230  1.0000    0.1222   1.0000
# 13  14/60   0.1213  1.0000    0.1206   1.0000
# 14  15/60   0.1198  1.0000    0.1196   1.0000
# 15  16/60   0.1185  1.0000    0.1182   1.0000
# 16  17/60   0.1174  1.0000    0.1171   1.0000
# 17  18/60   0.1164  1.0000    0.1162   1.0000
# 18  19/60   0.1154  1.0000    0.1152   1.0000
# ...

# %%
import plotly.graph_objects as go

# Assuming df contains the DataFrame with the metrics

# Create a figure for training and validation loss
fig_loss = go.Figure()

# Add training loss trace
fig_loss.add_trace(go.Scatter(x=df['epoch'], y=df['loss'], mode='lines+markers', name='Training Loss'))

# Add validation loss trace
fig_loss.add_trace(go.Scatter(x=df['epoch'], y=df['val_loss'], mode='lines+markers', name='Validation Loss'))

# Update layout
fig_loss.update_layout(title='Loss Metrics',
                      xaxis_title='Epoch',
                      yaxis_title='Value',
                      xaxis=dict(
                          tickmode='linear',
                          dtick=20,
                          tickfont=dict(size=20)  # Increase the tick font size
                      ),
                      title_font_size=30,  # Increase the title font size
                      yaxis=dict(
                          tickfont=dict(size=20),  # Increase the y-axis tick font size
                          title_font_size=25  # Increase the y-axis title font size
                      ),
                      xaxis_title_font_size=25,  # Increase the x-axis title font size
                      yaxis_title_font_size=25,  # Increase the y-axis title font size
                      legend=dict(
                          font=dict(size=20)  # Increase the legend font size
                      )
                    )

# Show the interactive plot
fig_loss.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Assuming df contains the DataFrame with the metrics

# Create a figure for training and validation accuracy
fig_accuracy = go.Figure()

# Add training accuracy trace
fig_accuracy.add_trace(go.Scatter(x=df['epoch'], y=df['acc'], mode='lines+markers', name='Training Accuracy'))

# Add validation accuracy trace
fig_accuracy.add_trace(go.Scatter(x=df['epoch'], y=df['val_acc'], mode='lines+markers', name='Validation Accuracy'))

# Update y-axis range to 0-1
fig_accuracy.update_yaxes(range=[0, 1])

# Update layout
fig_accuracy.update_layout(title='Accuracy Metrics',
                          xaxis_title='Epoch',
                          yaxis_title='Value',
                          xaxis=dict(
                              tickmode='linear',
                              dtick=10,  # Set tick interval to 10
                              tickfont=dict(size=20)  # Increase the tick font size
                          ),
                           title_font_size=30,  # Increase the title font size
                      yaxis=dict(
                          tickfont=dict(size=20),  # Increase the y-axis tick font size
                          title_font_size=25  # Increase the y-axis title font size
                      ),
                          xaxis_title_font_size=25,  # Increase the x-axis title font size
                          yaxis_title_font_size=25,  # Increase the y-axis title font size
                          legend=dict(
                              font=dict(size=20)  # Increase the legend font size
                          )
                          )

# Show the interactive plot
fig_accuracy.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
